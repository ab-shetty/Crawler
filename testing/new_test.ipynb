# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler

# Apply the patch to allow nested event loops
nest_asyncio.apply()

async def main():
    async with AsyncWebCrawler() as crawler:
        # Fetch a webpage and convert its HTML to Markdown
        result = await crawler.arun("https://example.com")
        print(result.markdown[:300])  # Print first 300 characters

# Now this works even in Jupyter/IPython
asyncio.run(main())
# Out:
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://example.com... | Status: True | Time: 1.05s
# [SCRAPE].. ◆ https://example.com... | Time: 0.012s
# [COMPLETE] ● https://example.com... | Status: True | Total: 1.08s
# # Example Domain
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# [More information...](https://www.iana.org/domains/example)

# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler

# Apply the patch to allow nested event loops
nest_asyncio.apply()

async def main():
    async with AsyncWebCrawler() as crawler:
        # Fetch a webpage and convert its HTML to Markdown
        result = await crawler.arun("https://example.com")
        print(result.markdown[:300])  # Print first 300 characters

# Now this works even in Jupyter/IPython
asyncio.run(main())
# Out:
# /home/ashetty/.pyenv/versions/3.10.14/lib/python3.10/ast.py:50: RuntimeWarning: coroutine 'main' was never awaited
#   return compile(source, filename, mode, flags,
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[3], line 15
#      12         print(result.markdown[:300])  # Print first 300 characters
#      14 # Now this works even in Jupyter/IPython
# ---> 15 asyncio.run(main())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[3], line 9, in main()
#       8 async def main():
# ----> 9     async with AsyncWebCrawler() as crawler:
#      10         # Fetch a webpage and convert its HTML to Markdown
#      11         result = await crawler.arun("https://example.com")
#      12         print(result.markdown[:300])
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_webcrawler.py:249, in AsyncWebCrawler.__aenter__(self)
#     248 async def __aenter__(self):
# --> 249     return await self.start()
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_webcrawler.py:233, in AsyncWebCrawler.start(self)
#     230         self.browser_config.cdp_url = browser_info.get('cdp_url')
#     231         self.browser_config.use_managed_browser = True
# --> 233 await self.crawler_strategy.__aenter__()
#     234 await self.awarmup()
#     235 return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:111, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     110 async def __aenter__(self):
# --> 111     await self.start()
#     112     return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:121, in AsyncPlaywrightCrawlerStrategy.start(self)
#     117 async def start(self):
#     118     """
#     119     Start the browser and initialize the browser manager.
#     120     """
# --> 121     await self.browser_manager.start()
#     122     await self.execute_hook(
#     123         "on_browser_created",
#     124         self.browser_manager.browser,
#     125         context=self.browser_manager.default_context,
#     126     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/browser_manager.py:520, in BrowserManager.start(self)
#     518     self.browser = await self.playwright.webkit.launch(**browser_args)
#     519 else:
# --> 520     self.browser = await self.playwright.chromium.launch(**browser_args)
#     522 self.default_context = self.browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/async_api/_generated.py:14450, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14332 async def launch(
#   14333     self,
#   14334     *,
#    (...)
#   14355     ] = None,
#   14356 ) -> "Browser":
#   14357     """BrowserType.launch
#   14358
#   14359     Returns the browser instance.
#    (...)
#   14446     Browser
#   14447     """
#   14449     return mapping.from_impl(
# > 14450         await self._impl_obj.launch(
#   14451             executablePath=executable_path,
#   14452             channel=channel,
#   14453             args=mapping.to_impl(args),
#   14454             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14455             handleSIGINT=handle_sigint,
#   14456             handleSIGTERM=handle_sigterm,
#   14457             handleSIGHUP=handle_sighup,
#   14458             timeout=timeout,
#   14459             env=mapping.to_impl(env),
#   14460             headless=headless,
#   14461             devtools=devtools,
#   14462             proxy=proxy,
#   14463             downloadsPath=downloads_path,
#   14464             slowMo=slow_mo,
#   14465             tracesDir=traces_dir,
#   14466             chromiumSandbox=chromium_sandbox,
#   14467             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14468         )
#   14469     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_browser_type.py:96, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      93 params = locals_to_params(locals())
#      94 normalize_launch_params(params)
#      95 browser = cast(
# ---> 96     Browser, from_channel(await self._channel.send("launch", params))
#      97 )
#      98 self._did_launch_browser(browser)
#      99 return browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TargetClosedError: BrowserType.launch: Target page, context or browser has been closed

# %%
import asyncio
import nest_asyncio
import os
import subprocess
import time
from crawl4ai import AsyncWebCrawler

# Apply nest_asyncio to allow nested event loops
nest_asyncio.apply()

# Function to kill lingering browser processes
def cleanup_browser_processes():
    """Kill any lingering Chromium/Chrome processes"""
    try:
        if os.name == 'posix':  # Linux/Mac
            subprocess.run(['pkill', '-f', 'chromium'], stderr=subprocess.DEVNULL)
            subprocess.run(['pkill', '-f', 'chrome'], stderr=subprocess.DEVNULL)
        elif os.name == 'nt':  # Windows
            subprocess.run(['taskkill', '/F', '/IM', 'chrome.exe'], stderr=subprocess.DEVNULL)
            subprocess.run(['taskkill', '/F', '/IM', 'chromium.exe'], stderr=subprocess.DEVNULL)
        # Give OS time to release resources
        time.sleep(1)
    except Exception as e:
        print(f"Process cleanup warning: {e}")

# Always clean up before starting
cleanup_browser_processes()

async def main():
    try:
        async with AsyncWebCrawler() as crawler:
            # Fetch a webpage and convert its HTML to Markdown
            result = await crawler.arun("https://example.com")
            print(result.markdown[:300])  # Print first 300 characters
    except Exception as e:
        print(f"Error during crawling: {e}")
        # Clean up on error
        cleanup_browser_processes()

# Now this works even in Jupyter/IPython
asyncio.run(main())
# Out:
# Error during crawling: BrowserType.launch: Target page, context or browser has been closed

# %%
import asyncio
import nest_asyncio
import uuid
from crawl4ai import AsyncWebCrawler, BrowserConfig

# Apply nest_asyncio
nest_asyncio.apply()

async def main():
    # Create a unique browser instance each time
    browser_config = BrowserConfig(
        browser_type="chromium",
        headless=True,
        # Use a unique browser ID each time
        browser_id=f"browser-{uuid.uuid4()}"
    )
    
    async with AsyncWebCrawler(config=browser_config) as crawler:
        result = await crawler.arun("https://example.com")
        print(result.markdown[:300])

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 22
#      19         result = await crawler.arun("https://example.com")
#      20         print(result.markdown[:300])
# ---> 22 asyncio.run(main())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[3], line 11, in main()
#       9 async def main():
#      10     # Create a unique browser instance each time
# ---> 11     browser_config = BrowserConfig(
#      12         browser_type="chromium",
#      13         headless=True,
#      14         # Use a unique browser ID each time
#      15         browser_id=f"browser-{uuid.uuid4()}"
#      16     )
#      18     async with AsyncWebCrawler(config=browser_config) as crawler:
#      19         result = await crawler.arun("https://example.com")
#
# TypeError: BrowserConfig.__init__() got an unexpected keyword argument 'browser_id'

# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler
import time

# Apply the patch to allow nested event loops
nest_asyncio.apply()

async def crawl_once(url="https://example.com"):
    crawler = AsyncWebCrawler()
    try:
        await crawler.start()
        # Fetch a webpage and convert its HTML to Markdown
        result = await crawler.arun(url)
        print(f"Crawl result for {url}:")
        print(result.markdown[:300])  # Print first 300 characters
        return result
    finally:
        # Ensure proper cleanup of all browser resources
        if hasattr(crawler, 'crawler_strategy') and crawler.crawler_strategy:
            if hasattr(crawler.crawler_strategy, 'browser_manager') and crawler.crawler_strategy.browser_manager:
                if hasattr(crawler.crawler_strategy.browser_manager, 'page') and crawler.crawler_strategy.browser_manager.page:
                    try:
                        await crawler.crawler_strategy.browser_manager.page.unroute_all(behavior="ignore_errors")
                    except Exception as e:
                        print(f"Unroute warning: {e}")
        await crawler.close()

async def main():
    print("Starting first crawl...")
    await crawl_once()
    
    # Add a small delay between crawls to ensure complete cleanup
    time.sleep(1)
    
    print("\nStarting second crawl...")
    await crawl_once()

# Run both crawls in sequence
asyncio.run(main())
# Out:
# Starting first crawl...
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://example.com... | Status: True | Time: 1.29s
# [SCRAPE].. ◆ https://example.com... | Time: 0.006s
# [COMPLETE] ● https://example.com... | Status: True | Total: 1.31s
# Crawl result for https://example.com:
# # Example Domain
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# [More information...](https://www.iana.org/domains/example)
#
#
# Starting second crawl...
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[1], line 40
#      37     await crawl_once()
#      39 # Run both crawls in sequence
# ---> 40 asyncio.run(main())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[1], line 37, in main()
#      34 time.sleep(1)
#      36 print("\nStarting second crawl...")
# ---> 37 await crawl_once()
#
# Cell In[1], line 12, in crawl_once(url)
#      10 crawler = AsyncWebCrawler()
#      11 try:
# ---> 12     await crawler.start()
#      13     # Fetch a webpage and convert its HTML to Markdown
#      14     result = await crawler.arun(url)
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_webcrawler.py:233, in AsyncWebCrawler.start(self)
#     230         self.browser_config.cdp_url = browser_info.get('cdp_url')
#     231         self.browser_config.use_managed_browser = True
# --> 233 await self.crawler_strategy.__aenter__()
#     234 await self.awarmup()
#     235 return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:111, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     110 async def __aenter__(self):
# --> 111     await self.start()
#     112     return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:121, in AsyncPlaywrightCrawlerStrategy.start(self)
#     117 async def start(self):
#     118     """
#     119     Start the browser and initialize the browser manager.
#     120     """
# --> 121     await self.browser_manager.start()
#     122     await self.execute_hook(
#     123         "on_browser_created",
#     124         self.browser_manager.browser,
#     125         context=self.browser_manager.default_context,
#     126     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/browser_manager.py:520, in BrowserManager.start(self)
#     518     self.browser = await self.playwright.webkit.launch(**browser_args)
#     519 else:
# --> 520     self.browser = await self.playwright.chromium.launch(**browser_args)
#     522 self.default_context = self.browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/async_api/_generated.py:14450, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14332 async def launch(
#   14333     self,
#   14334     *,
#    (...)
#   14355     ] = None,
#   14356 ) -> "Browser":
#   14357     """BrowserType.launch
#   14358
#   14359     Returns the browser instance.
#    (...)
#   14446     Browser
#   14447     """
#   14449     return mapping.from_impl(
# > 14450         await self._impl_obj.launch(
#   14451             executablePath=executable_path,
#   14452             channel=channel,
#   14453             args=mapping.to_impl(args),
#   14454             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14455             handleSIGINT=handle_sigint,
#   14456             handleSIGTERM=handle_sigterm,
#   14457             handleSIGHUP=handle_sighup,
#   14458             timeout=timeout,
#   14459             env=mapping.to_impl(env),
#   14460             headless=headless,
#   14461             devtools=devtools,
#   14462             proxy=proxy,
#   14463             downloadsPath=downloads_path,
#   14464             slowMo=slow_mo,
#   14465             tracesDir=traces_dir,
#   14466             chromiumSandbox=chromium_sandbox,
#   14467             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14468         )
#   14469     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_browser_type.py:96, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      93 params = locals_to_params(locals())
#      94 normalize_launch_params(params)
#      95 browser = cast(
# ---> 96     Browser, from_channel(await self._channel.send("launch", params))
#      97 )
#      98 self._did_launch_browser(browser)
#      99 return browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TargetClosedError: BrowserType.launch: Target page, context or browser has been closed

# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler, CacheMode, CrawlerRunConfig

# Patch asyncio to allow nested event loops (useful in Jupyter/IPython)
nest_asyncio.apply()

async def crawl_once(url: str = "https://example.com"):
    crawler = AsyncWebCrawler()
    try:
        await crawler.start()
        
        # Optional: Define crawl config, e.g., bypass cache
        run_config = CrawlerRunConfig(cache_mode=CacheMode.BYPASS)
        
        # Run the crawler on the URL
        result = await crawler.arun(url, config=run_config)
        
        # Print first 300 characters of markdown content
        print(f"Crawl result for {url}:\n{result.markdown[:300]}\n")
        
        # If you have access to the page, unroute all routes to avoid TargetClosedError
        # This is a safeguard if you use page.route() in your code (optional)
        if hasattr(crawler, 'crawler_strategy') and crawler.crawler_strategy:
            browser_manager = crawler.crawler_strategy.browser_manager
            if browser_manager and hasattr(browser_manager, 'default_context'):
                context = browser_manager.default_context
                try:
                    await context.unroute_all(behavior="ignore_errors")
                except Exception as e:
                    print(f"Warning during unroute_all: {e}")
    finally:
        # Ensure crawler is properly closed to clean up browser processes
        await crawler.close()

async def main():
    print("Starting first crawl...")
    await crawl_once("https://example.com")
    
    # Small delay to ensure OS-level cleanup (optional but recommended)
    await asyncio.sleep(1)
    
    print("Starting second crawl...")
    await crawl_once("https://example.com")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Starting first crawl...
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://example.com... | Status: True | Time: 1.11s
# [SCRAPE].. ◆ https://example.com... | Time: 0.01s
# [COMPLETE] ● https://example.com... | Status: True | Total: 1.14s
# Crawl result for https://example.com:
# # Example Domain
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# [More information...](https://www.iana.org/domains/example)
#
#
# Warning during unroute_all: 'Browser' object has no attribute 'unroute_all'
# Starting second crawl...
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[1], line 47
#      44     await crawl_once("https://example.com")
#      46 if __name__ == "__main__":
# ---> 47     asyncio.run(main())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[1], line 44, in main()
#      41 await asyncio.sleep(1)
#      43 print("Starting second crawl...")
# ---> 44 await crawl_once("https://example.com")
#
# Cell In[1], line 11, in crawl_once(url)
#       9 crawler = AsyncWebCrawler()
#      10 try:
# ---> 11     await crawler.start()
#      13     # Optional: Define crawl config, e.g., bypass cache
#      14     run_config = CrawlerRunConfig(cache_mode=CacheMode.BYPASS)
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_webcrawler.py:233, in AsyncWebCrawler.start(self)
#     230         self.browser_config.cdp_url = browser_info.get('cdp_url')
#     231         self.browser_config.use_managed_browser = True
# --> 233 await self.crawler_strategy.__aenter__()
#     234 await self.awarmup()
#     235 return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:111, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     110 async def __aenter__(self):
# --> 111     await self.start()
#     112     return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:121, in AsyncPlaywrightCrawlerStrategy.start(self)
#     117 async def start(self):
#     118     """
#     119     Start the browser and initialize the browser manager.
#     120     """
# --> 121     await self.browser_manager.start()
#     122     await self.execute_hook(
#     123         "on_browser_created",
#     124         self.browser_manager.browser,
#     125         context=self.browser_manager.default_context,
#     126     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/browser_manager.py:520, in BrowserManager.start(self)
#     518     self.browser = await self.playwright.webkit.launch(**browser_args)
#     519 else:
# --> 520     self.browser = await self.playwright.chromium.launch(**browser_args)
#     522 self.default_context = self.browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/async_api/_generated.py:14450, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14332 async def launch(
#   14333     self,
#   14334     *,
#    (...)
#   14355     ] = None,
#   14356 ) -> "Browser":
#   14357     """BrowserType.launch
#   14358
#   14359     Returns the browser instance.
#    (...)
#   14446     Browser
#   14447     """
#   14449     return mapping.from_impl(
# > 14450         await self._impl_obj.launch(
#   14451             executablePath=executable_path,
#   14452             channel=channel,
#   14453             args=mapping.to_impl(args),
#   14454             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14455             handleSIGINT=handle_sigint,
#   14456             handleSIGTERM=handle_sigterm,
#   14457             handleSIGHUP=handle_sighup,
#   14458             timeout=timeout,
#   14459             env=mapping.to_impl(env),
#   14460             headless=headless,
#   14461             devtools=devtools,
#   14462             proxy=proxy,
#   14463             downloadsPath=downloads_path,
#   14464             slowMo=slow_mo,
#   14465             tracesDir=traces_dir,
#   14466             chromiumSandbox=chromium_sandbox,
#   14467             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14468         )
#   14469     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_browser_type.py:96, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      93 params = locals_to_params(locals())
#      94 normalize_launch_params(params)
#      95 browser = cast(
# ---> 96     Browser, from_channel(await self._channel.send("launch", params))
#      97 )
#      98 self._did_launch_browser(browser)
#      99 return browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TargetClosedError: BrowserType.launch: Target page, context or browser has been closed

# %%
import asyncio
import nest_asyncio
import os
import subprocess
import time
from crawl4ai import AsyncWebCrawler, CacheMode, CrawlerRunConfig

# Patch asyncio to allow nested event loops
nest_asyncio.apply()

# Function to forcibly kill browser processes
def kill_browser_processes():
    """Kill any lingering browser processes to ensure clean state"""
    try:
        if os.name == 'posix':  # Linux/Mac
            subprocess.run(['pkill', '-f', 'chromium'], stderr=subprocess.DEVNULL)
            subprocess.run(['pkill', '-f', 'chrome'], stderr=subprocess.DEVNULL)
        elif os.name == 'nt':  # Windows
            subprocess.run(['taskkill', '/F', '/IM', 'chrome.exe'], stderr=subprocess.DEVNULL)
            subprocess.run(['taskkill', '/F', '/IM', 'chromium.exe'], stderr=subprocess.DEVNULL)
    except Exception as e:
        print(f"Warning during process cleanup: {e}")
    
    # Give OS time to release resources
    time.sleep(1)

async def crawl_once(url: str = "https://example.com"):
    # Kill any lingering browser processes before starting
    kill_browser_processes()
    
    crawler = AsyncWebCrawler()
    try:
        await crawler.start()
        
        # Define crawl config with bypass cache to avoid stale data
        run_config = CrawlerRunConfig(
            cache_mode=CacheMode.BYPASS,
            page_timeout=30000  # 30 seconds timeout
        )
        
        # Run the crawler on the URL
        result = await crawler.arun(url, config=run_config)
        
        # Print first 300 characters of markdown content
        print(f"Crawl result for {url}:\n{result.markdown[:300]}\n")
        return result
    except Exception as e:
        print(f"Error during crawling: {e}")
        raise
    finally:
        # Ensure crawler is properly closed
        try:
            await crawler.close()
        except Exception as e:
            print(f"Warning during crawler close: {e}")
        
        # Force kill any remaining browser processes
        kill_browser_processes()

async def main():
    print("Starting first crawl...")
    await crawl_once("https://example.com")
    
    print("Starting second crawl...")
    await crawl_once("https://example.com")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Starting first crawl...
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://example.com... | Status: True | Time: 1.07s
# [SCRAPE].. ◆ https://example.com... | Time: 0.01s
# [COMPLETE] ● https://example.com... | Status: True | Total: 1.11s
# Crawl result for https://example.com:
# # Example Domain
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# [More information...](https://www.iana.org/domains/example)
#
#
# Starting second crawl...
# Error during crawling: BrowserType.launch: Target page, context or browser has been closed
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[1], line 68
#      65     await crawl_once("https://example.com")
#      67 if __name__ == "__main__":
# ---> 68     asyncio.run(main())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[1], line 65, in main()
#      62 await crawl_once("https://example.com")
#      64 print("Starting second crawl...")
# ---> 65 await crawl_once("https://example.com")
#
# Cell In[1], line 33, in crawl_once(url)
#      31 crawler = AsyncWebCrawler()
#      32 try:
# ---> 33     await crawler.start()
#      35     # Define crawl config with bypass cache to avoid stale data
#      36     run_config = CrawlerRunConfig(
#      37         cache_mode=CacheMode.BYPASS,
#      38         page_timeout=30000  # 30 seconds timeout
#      39     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_webcrawler.py:233, in AsyncWebCrawler.start(self)
#     230         self.browser_config.cdp_url = browser_info.get('cdp_url')
#     231         self.browser_config.use_managed_browser = True
# --> 233 await self.crawler_strategy.__aenter__()
#     234 await self.awarmup()
#     235 return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:111, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     110 async def __aenter__(self):
# --> 111     await self.start()
#     112     return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:121, in AsyncPlaywrightCrawlerStrategy.start(self)
#     117 async def start(self):
#     118     """
#     119     Start the browser and initialize the browser manager.
#     120     """
# --> 121     await self.browser_manager.start()
#     122     await self.execute_hook(
#     123         "on_browser_created",
#     124         self.browser_manager.browser,
#     125         context=self.browser_manager.default_context,
#     126     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/browser_manager.py:520, in BrowserManager.start(self)
#     518     self.browser = await self.playwright.webkit.launch(**browser_args)
#     519 else:
# --> 520     self.browser = await self.playwright.chromium.launch(**browser_args)
#     522 self.default_context = self.browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/async_api/_generated.py:14450, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14332 async def launch(
#   14333     self,
#   14334     *,
#    (...)
#   14355     ] = None,
#   14356 ) -> "Browser":
#   14357     """BrowserType.launch
#   14358
#   14359     Returns the browser instance.
#    (...)
#   14446     Browser
#   14447     """
#   14449     return mapping.from_impl(
# > 14450         await self._impl_obj.launch(
#   14451             executablePath=executable_path,
#   14452             channel=channel,
#   14453             args=mapping.to_impl(args),
#   14454             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14455             handleSIGINT=handle_sigint,
#   14456             handleSIGTERM=handle_sigterm,
#   14457             handleSIGHUP=handle_sighup,
#   14458             timeout=timeout,
#   14459             env=mapping.to_impl(env),
#   14460             headless=headless,
#   14461             devtools=devtools,
#   14462             proxy=proxy,
#   14463             downloadsPath=downloads_path,
#   14464             slowMo=slow_mo,
#   14465             tracesDir=traces_dir,
#   14466             chromiumSandbox=chromium_sandbox,
#   14467             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14468         )
#   14469     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_browser_type.py:96, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      93 params = locals_to_params(locals())
#      94 normalize_launch_params(params)
#      95 browser = cast(
# ---> 96     Browser, from_channel(await self._channel.send("launch", params))
#      97 )
#      98 self._did_launch_browser(browser)
#      99 return browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TargetClosedError: BrowserType.launch: Target page, context or browser has been closed

# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler

nest_asyncio.apply()

async def crawl_once(url):
    crawler = AsyncWebCrawler()
    await crawler.start()
    try:
        result = await crawler.arun(url)
        print(result.markdown[:300])
    finally:
        await crawler.close()

async def main():
    print("First crawl:")
    await crawl_once("https://example.com")
    print("\nSecond crawl:")
    await crawl_once("https://example.com")

asyncio.run(main())
# Out:
# First crawl:
# [INIT].... → Crawl4AI 0.5.0.post8
# [FETCH]... ↓ https://example.com... | Status: True | Time: 1.23s
# [SCRAPE].. ◆ https://example.com... | Time: 0.006s
# [COMPLETE] ● https://example.com... | Status: True | Total: 1.26s
# # Example Domain
# This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.
# [More information...](https://www.iana.org/domains/example)
#
#
# Second crawl:
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# Cell In[1], line 22
#      19     print("\nSecond crawl:")
#      20     await crawl_once("https://example.com")
# ---> 22 asyncio.run(main())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[1], line 20, in main()
#      18 await crawl_once("https://example.com")
#      19 print("\nSecond crawl:")
# ---> 20 await crawl_once("https://example.com")
#
# Cell In[1], line 9, in crawl_once(url)
#       7 async def crawl_once(url):
#       8     crawler = AsyncWebCrawler()
# ----> 9     await crawler.start()
#      10     try:
#      11         result = await crawler.arun(url)
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_webcrawler.py:233, in AsyncWebCrawler.start(self)
#     230         self.browser_config.cdp_url = browser_info.get('cdp_url')
#     231         self.browser_config.use_managed_browser = True
# --> 233 await self.crawler_strategy.__aenter__()
#     234 await self.awarmup()
#     235 return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:111, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     110 async def __aenter__(self):
# --> 111     await self.start()
#     112     return self
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/async_crawler_strategy.py:121, in AsyncPlaywrightCrawlerStrategy.start(self)
#     117 async def start(self):
#     118     """
#     119     Start the browser and initialize the browser manager.
#     120     """
# --> 121     await self.browser_manager.start()
#     122     await self.execute_hook(
#     123         "on_browser_created",
#     124         self.browser_manager.browser,
#     125         context=self.browser_manager.default_context,
#     126     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/crawl4ai/browser_manager.py:520, in BrowserManager.start(self)
#     518     self.browser = await self.playwright.webkit.launch(**browser_args)
#     519 else:
# --> 520     self.browser = await self.playwright.chromium.launch(**browser_args)
#     522 self.default_context = self.browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/async_api/_generated.py:14450, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14332 async def launch(
#   14333     self,
#   14334     *,
#    (...)
#   14355     ] = None,
#   14356 ) -> "Browser":
#   14357     """BrowserType.launch
#   14358
#   14359     Returns the browser instance.
#    (...)
#   14446     Browser
#   14447     """
#   14449     return mapping.from_impl(
# > 14450         await self._impl_obj.launch(
#   14451             executablePath=executable_path,
#   14452             channel=channel,
#   14453             args=mapping.to_impl(args),
#   14454             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14455             handleSIGINT=handle_sigint,
#   14456             handleSIGTERM=handle_sigterm,
#   14457             handleSIGHUP=handle_sighup,
#   14458             timeout=timeout,
#   14459             env=mapping.to_impl(env),
#   14460             headless=headless,
#   14461             devtools=devtools,
#   14462             proxy=proxy,
#   14463             downloadsPath=downloads_path,
#   14464             slowMo=slow_mo,
#   14465             tracesDir=traces_dir,
#   14466             chromiumSandbox=chromium_sandbox,
#   14467             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14468         )
#   14469     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_browser_type.py:96, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      93 params = locals_to_params(locals())
#      94 normalize_launch_params(params)
#      95 browser = cast(
# ---> 96     Browser, from_channel(await self._channel.send("launch", params))
#      97 )
#      98 self._did_launch_browser(browser)
#      99 return browser
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/Crawler/venv/lib/python3.10/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     526     return await cb()
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#     530     self._api_zone.set(None)
#
# TargetClosedError: BrowserType.launch: Target page, context or browser has been closed

# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler

nest_asyncio.apply()
from crawl4ai.async_configs import BrowserConfig, CrawlerRunConfig
from crawl4ai.cache_context import CacheMode

async def basic_session_crawl():
    async with AsyncWebCrawler() as crawler:
        session_id = "dynamic_content_session"
        url = "https://example.com/dynamic-content"

        for page in range(3):
            config = CrawlerRunConfig(
                url=url,
                session_id=session_id,
                js_code="document.querySelector('.load-more-button').click();" if page > 0 else None,
                css_selector=".content-item",
                cache_mode=CacheMode.BYPASS
            )

            result = await crawler.arun(config=config)
            print(f"Page {page + 1}: Found {result.extracted_content.count('.content-item')} items")

        await crawler.crawler_strategy.kill_session(session_id)

asyncio.run(basic_session_crawl())
# Out:
# [INIT].... → Crawl4AI 0.5.0.post8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 28
#      24             print(f"Page {page + 1}: Found {result.extracted_content.count('.content-item')} items")
#      26         await crawler.crawler_strategy.kill_session(session_id)
# ---> 28 asyncio.run(basic_session_crawl())
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Crawler/venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[2], line 23, in basic_session_crawl()
#      14 for page in range(3):
#      15     config = CrawlerRunConfig(
#      16         url=url,
#      17         session_id=session_id,
#    (...)
#      20         cache_mode=CacheMode.BYPASS
#      21     )
# ---> 23     result = await crawler.arun(config=config)
#      24     print(f"Page {page + 1}: Found {result.extracted_content.count('.content-item')} items")
#      26 await crawler.crawler_strategy.kill_session(session_id)
#
# TypeError: AsyncWebCrawler.arun() missing 1 required positional argument: 'url'
